# %%
# !pip install matplotlib

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 8, 7]

plt.scatter(x, y)
plt.title("Gráfico de Dispersão")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.3 MB 9.3 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.3 MB 7.9 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.3 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.3 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 9.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------------------------- ---- 2.1/2.3 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.4 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/6 [pyparsing]
#    ---------------------------------------- 0/6 [pyparsing]
#    ---------------------------------------- 0/6 [pyparsing]
#    ------ --------------------------------- 1/6 [kiwisolver]
#    ------------- -------------------------- 2/6 [fonttools]
# ...
